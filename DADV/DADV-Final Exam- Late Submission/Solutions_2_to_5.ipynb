# %% [markdown]
# # 2.	If we define daily gain or loss of a stock is the % of change of the stock closing price to previous day closing price. Compute daily gain or loss for each S&P500 company. Do the same thing for weekly and monthly gains or losses.

# %%
#importing required necessary libraries to perform analysis.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations

# %%
#improting necessary libraries to scrape the data.
#using pool method to multiprocessing for download faster.
import requests
import urllib
from bs4 import BeautifulSoup
import re
import io
import gzip
import time
import csv
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from multiprocessing import Pool
import import_ipynb
import pandas as pd
from ipynb.fs.full.scraping_daily_data import scraping_daily_data

driver = webdriver.Chrome(ChromeDriverManager().install())
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
driver.get(url)

symbols = list()
symbols_GICC = dict()

table = "/html/body/div[3]/div[3]/div[5]/div[1]/table[1]"
table = driver.find_element_by_xpath(table)
elements = table.find_elements_by_tag_name("tr")[1:]

for row in elements:
    data = [data.text for data in row.find_elements_by_tag_name("td")]
    #here i am storung all the data related to a date in a dictioanry.
    symbols.append(data[0])
    symbols_GICC[data[0]] = data[3]

print(len(symbols_GICC))
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Ranjith\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# 505

# %%
#here computing daily gain or loss for each company for daily stocks, weekly an dmonthly
gain_loss_daily = pd.DataFrame(columns=["symbol","gain_loss","GICS"])
gain_loss_weekly = pd.DataFrame(columns=["symbol","gain_loss","GICS"])
gain_loss_monthly = pd.DataFrame(columns=["symbol","gain_loss","GICS"])

# %%
daily_dfs = {}
weekly_dfs = {}
monthly_dfs = {}


def gain_loss(sym):
    #DAILY
    #reading the csv file every file ends with daily for daily stock.
    df_daily = pd.read_csv(sym +"_daily" + ".csv")
    #here as told in question, applying formula. previous day-present closing price/present clsoing price.
    #here shit(1) means it takes the previous available value in dataframe.
    df_daily["Gain/Loss"] = (df_daily["Close"] - df_daily["Close"].shift(1)) / df_daily["Close"]
    
    #here daily gain/loss is gievn for every ticker symbol.
    daily_dfs[sym] = df_daily
    
    #WEEKLY
    df_weekly = pd.read_csv(sym +"_weekly"+".csv")
    df_weekly["Gain/Loss"] = (df_weekly["Close"] - df_weekly["Close"].shift(1)) / df_weekly["Close"]
    weekly_dfs[sym] = df_weekly
    
    #MONTHLY
    df_monthly = pd.read_csv(sym + "_monthly" + ".csv")
    df_monthly["Gain/Loss"] = (df_monthly["Close"] - df_monthly["Close"].shift(1)) / df_weekly["Close"]
    monthly_dfs[sym] = df_monthly
    
    #Here creating a dictionary to store all the gain/loss for all symbols by calling the gain_loss method.
    daily = {"symbol":sym,"gain_loss":df_daily["Gain/Loss"].sum(),"GICS":symbols_GICC[sym]}
    weekly = {"symbol":sym,"gain_loss":df_weekly["Gain/Loss"].sum(),"GICS":symbols_GICC[sym]}
    monthly = {"symbol":sym,"gain_loss":df_monthly["Gain/Loss"].sum(),"GICS":symbols_GICC[sym]}
    
    return (daily,weekly,monthly)

# %%
for n in symbols:
    try:
        (daily,weekly,monthly) = gain_loss(n)
        #now inserting all the method call values in dataframes created earlier.
        gain_loss_daily = gain_loss_daily.append(daily, ignore_index=True)
        #here for each df, creating an index and 3 columsn.
        gain_loss_weekly = gain_loss_weekly.append(weekly, ignore_index=True)
        gain_loss_monthly = gain_loss_monthly.append(monthly, ignore_index=True)
    except Exception as e:
        pass

# %%
print(gain_loss_daily)
print(gain_loss_weekly)
print(gain_loss_monthly)
# Out:
#     symbol  gain_loss                    GICS
# 0      MMM   0.022650             Industrials
# 1      ABT   0.775921             Health Care
# 2     ABBV   0.402984             Health Care
# 3     ABMD   0.868232             Health Care
# 4      ACN   0.782966  Information Technology
# ..     ...        ...                     ...
# 241    MKC   0.673513        Consumer Staples
# 242    MDT   0.285405             Health Care
# 243   MCHP   0.731854  Information Technology
# 244    TAP  -0.941475        Consumer Staples
# 245     MS   0.475200              Financials
#
# [246 rows x 3 columns]
#     symbol  gain_loss                    GICS
# 0      MMM   0.076890             Industrials
# 1      ABT   0.847760             Health Care
# 2     ABBV   0.435138             Health Care
# 3     ABMD   0.891735             Health Care
# 4      ACN   0.828857  Information Technology
# ..     ...        ...                     ...
# 241    MKC   0.708544        Consumer Staples
# 242    MDT   0.316487             Health Care
# 243   MCHP   0.802615  Information Technology
# 244    TAP  -0.957985        Consumer Staples
# 245     MS   0.561547              Financials
#
# [246 rows x 3 columns]
#     symbol  gain_loss                    GICS
# 0      MMM   0.180066             Industrials
# 1      ABT   2.063769             Health Care
# 2     ABBV   0.796004             Health Care
# 3     ABMD   2.500622             Health Care
# 4      ACN   1.193002  Information Technology
# ..     ...        ...                     ...
# 241    MKC   0.962392        Consumer Staples
# 242    MDT   0.430314             Health Care
# 243   MCHP   1.637921  Information Technology
# 244    TAP  -0.376565        Consumer Staples
# 245     MS   1.253259              Financials
#
# [246 rows x 3 columns]

# %% [markdown]
# # 3.	Top 25 gainers of S&P 500 for 1000 trading days are the companies which have max % gain during those 1000 trading days. Bottom 25 gainers of S&P 500 for 1000 trading days are the companies which have least % gain (it can be negative gain too which is loss) during those 1000 trading days. Compute and draw the correlation matrix for the top 25 and bottom 25 companies for daily gains or losses. This is a matrix with both axes holding the stock names. The color of each cell is the correlation between that pair of stocks: red for -1 and blue for 1. Do the same thing for weekly and monthly gains or losses.

# %%
#sorting the values as it asked for top values only.
gain_loss_daily = gain_loss_daily.sort_values(by=["gain_loss"])

#this gives us the top 25 gain values
gain_25_daily = gain_loss_daily.head(25)

#this gives bottom loss values
loss_25_daily = gain_loss_daily.tail(25)

#here ticker symbols are company names
gain_25_daily_names = list(gain_25_daily["symbol"])
loss_25_daily_names = list(loss_25_daily["symbol"])

#now for correlation matrix we need to find the combined relation by combining gain and loss names.
names = set(loss_25_daily_names+gain_25_daily_names)
samp = pd.DataFrame(columns=names,index=names)

for n1,n2 in combinations(names,2):
    df1 = daily_dfs[n1]
    df2 = daily_dfs[n2]
    samp.loc[n1,n2] = df1["Gain/Loss"].corr(df2["Gain/Loss"])
    samp.loc[n2,n1] = df2["Gain/Loss"].corr(df1["Gain/Loss"])
    samp.loc[n1,n1] = 1
    samp.loc[n2,n2] = 1
daily_samp = samp.astype({name:"float" for name in names})
daily_samp.style.background_gradient(cmap="brg")
# Out:
# <style  type="text/css" >
# #T_c0b8e_row0_col0,#T_c0b8e_row1_col1,#T_c0b8e_row2_col2,#T_c0b8e_row3_col3,#T_c0b8e_row4_col4,#T_c0b8e_row5_col5,#T_c0b8e_row6_col6,#T_c0b8e_row7_col7,#T_c0b8e_row8_col8,#T_c0b8e_row9_col9,#T_c0b8e_row10_col10,#T_c0b8e_row11_col11,#T_c0b8e_row12_col12,#T_c0b8e_row13_col13,#T_c0b8e_row14_col14,#T_c0b8e_row15_col15,#T_c0b8e_row16_col16,#T_c0b8e_row17_col17,#T_c0b8e_row18_col18,#T_c0b8e_row19_col19,#T_c0b8e_row20_col20,#T_c0b8e_row21_col21,#T_c0b8e_row22_col22,#T_c0b8e_row23_col23,#T_c0b8e_row24_col24,#T_c0b8e_row25_col25,#T_c0b8e_row26_col26,#T_c0b8e_row27_col27,#T_c0b8e_row28_col28,#T_c0b8e_row29_col29,#T_c0b8e_row30_col30,#T_c0b8e_row31_col31,#T_c0b8e_row32_col32,#T_c0b8e_row33_col33,#T_c0b8e_row34_col34,#T_c0b8e_row35_col35,#T_c0b8e_row36_col36,#T_c0b8e_row37_col37,#T_c0b8e_row38_col38,#T_c0b8e_row39_col39,#T_c0b8e_row40_col40,#T_c0b8e_row41_col41,#T_c0b8e_row42_col42,#T_c0b8e_row43_col43,#T_c0b8e_row44_col44,#T_c0b8e_row45_col45,#T_c0b8e_row46_col46,#T_c0b8e_row47_col47,#T_c0b8e_row48_col48,#T_c0b8e_row49_col49{
#             background-color:  #00ff00;
#             color:  #000000;
#         }#T_c0b8e_row0_col1,#T_c0b8e_row0_col23,#T_c0b8e_row3_col44,#T_c0b8e_row10_col8,#T_c0b8e_row14_col13,#T_c0b8e_row17_col43,#T_c0b8e_row19_col14,#T_c0b8e_row19_col41,#T_c0b8e_row20_col13,#T_c0b8e_row20_col21,#T_c0b8e_row20_col24,#T_c0b8e_row29_col10,#T_c0b8e_row35_col40,#T_c0b8e_row44_col1,#T_c0b8e_row44_col43,#T_c0b8e_row48_col2,#T_c0b8e_row48_col24{
#             background-color:  #1400eb;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col2,#T_c0b8e_row0_col36,#T_c0b8e_row0_col41,#T_c0b8e_row3_col39,#T_c0b8e_row10_col44,#T_c0b8e_row10_col48,#T_c0b8e_row12_col40,#T_c0b8e_row15_col38,#T_c0b8e_row19_col49,#T_c0b8e_row20_col37,#T_c0b8e_row20_col39,#T_c0b8e_row21_col40,#T_c0b8e_row27_col10,#T_c0b8e_row28_col20,#T_c0b8e_row28_col31,#T_c0b8e_row29_col28,#T_c0b8e_row30_col15,#T_c0b8e_row34_col13,#T_c0b8e_row38_col19{
#             background-color:  #2800d7;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col3,#T_c0b8e_row0_col31,#T_c0b8e_row6_col26,#T_c0b8e_row6_col34,#T_c0b8e_row6_col37,#T_c0b8e_row6_col40,#T_c0b8e_row9_col13,#T_c0b8e_row12_col31,#T_c0b8e_row23_col18,#T_c0b8e_row23_col26,#T_c0b8e_row28_col22,#T_c0b8e_row28_col38,#T_c0b8e_row33_col14,#T_c0b8e_row33_col20,#T_c0b8e_row39_col2,#T_c0b8e_row39_col16,#T_c0b8e_row40_col7,#T_c0b8e_row40_col39,#T_c0b8e_row43_col9,#T_c0b8e_row45_col43{
#             background-color:  #5400ab;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col4,#T_c0b8e_row1_col28,#T_c0b8e_row2_col11,#T_c0b8e_row4_col8,#T_c0b8e_row5_col23,#T_c0b8e_row11_col25,#T_c0b8e_row11_col40,#T_c0b8e_row13_col4,#T_c0b8e_row16_col9,#T_c0b8e_row21_col35,#T_c0b8e_row24_col28,#T_c0b8e_row26_col22,#T_c0b8e_row27_col48,#T_c0b8e_row31_col37,#T_c0b8e_row32_col29,#T_c0b8e_row38_col33,#T_c0b8e_row41_col18,#T_c0b8e_row41_col49,#T_c0b8e_row42_col12,#T_c0b8e_row45_col8,#T_c0b8e_row47_col49,#T_c0b8e_row48_col17{
#             background-color:  #a2005d;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col5,#T_c0b8e_row5_col38,#T_c0b8e_row5_col45,#T_c0b8e_row5_col48,#T_c0b8e_row8_col23,#T_c0b8e_row10_col30,#T_c0b8e_row12_col1,#T_c0b8e_row14_col31,#T_c0b8e_row19_col28,#T_c0b8e_row20_col17,#T_c0b8e_row21_col13,#T_c0b8e_row33_col3,#T_c0b8e_row33_col5,#T_c0b8e_row38_col20{
#             background-color:  #3600c9;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col6,#T_c0b8e_row3_col33,#T_c0b8e_row10_col25,#T_c0b8e_row17_col28,#T_c0b8e_row20_col0,#T_c0b8e_row21_col2,#T_c0b8e_row21_col37,#T_c0b8e_row33_col24,#T_c0b8e_row34_col19,#T_c0b8e_row35_col19,#T_c0b8e_row44_col19{
#             background-color:  #1800e7;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col7,#T_c0b8e_row0_col25,#T_c0b8e_row2_col46,#T_c0b8e_row6_col28,#T_c0b8e_row6_col45,#T_c0b8e_row12_col0,#T_c0b8e_row12_col25,#T_c0b8e_row13_col34,#T_c0b8e_row13_col48,#T_c0b8e_row14_col30,#T_c0b8e_row14_col45,#T_c0b8e_row18_col13,#T_c0b8e_row18_col31,#T_c0b8e_row19_col5,#T_c0b8e_row22_col19,#T_c0b8e_row22_col20,#T_c0b8e_row23_col13,#T_c0b8e_row31_col35,#T_c0b8e_row32_col34,#T_c0b8e_row40_col19,#T_c0b8e_row40_col28,#T_c0b8e_row41_col26,#T_c0b8e_row41_col47,#T_c0b8e_row42_col35,#T_c0b8e_row47_col31,#T_c0b8e_row47_col36,#T_c0b8e_row49_col8{
#             background-color:  #760089;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col8,#T_c0b8e_row8_col43,#T_c0b8e_row10_col16,#T_c0b8e_row10_col17,#T_c0b8e_row12_col5,#T_c0b8e_row14_col17,#T_c0b8e_row14_col25,#T_c0b8e_row16_col0,#T_c0b8e_row19_col10,#T_c0b8e_row26_col23,#T_c0b8e_row26_col32,#T_c0b8e_row27_col36,#T_c0b8e_row33_col40,#T_c0b8e_row39_col32,#T_c0b8e_row43_col27,#T_c0b8e_row43_col30,#T_c0b8e_row43_col33,#T_c0b8e_row44_col8,#T_c0b8e_row44_col20,#T_c0b8e_row45_col23,#T_c0b8e_row47_col19,#T_c0b8e_row48_col14,#T_c0b8e_row48_col20{
#             background-color:  #4800b7;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col9,#T_c0b8e_row4_col34,#T_c0b8e_row5_col16,#T_c0b8e_row5_col43,#T_c0b8e_row7_col16,#T_c0b8e_row8_col35,#T_c0b8e_row9_col21,#T_c0b8e_row11_col2,#T_c0b8e_row11_col4,#T_c0b8e_row12_col39,#T_c0b8e_row13_col18,#T_c0b8e_row16_col12,#T_c0b8e_row30_col35,#T_c0b8e_row34_col47,#T_c0b8e_row35_col34,#T_c0b8e_row35_col48,#T_c0b8e_row37_col48,#T_c0b8e_row38_col22,#T_c0b8e_row41_col22,#T_c0b8e_row42_col11,#T_c0b8e_row43_col10,#T_c0b8e_row43_col28,#T_c0b8e_row43_col42,#T_c0b8e_row48_col35,#T_c0b8e_row49_col15,#T_c0b8e_row49_col41{
#             background-color:  #a80057;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col10,#T_c0b8e_row0_col20,#T_c0b8e_row0_col37,#T_c0b8e_row3_col8,#T_c0b8e_row8_col10,#T_c0b8e_row9_col19,#T_c0b8e_row9_col36,#T_c0b8e_row10_col18,#T_c0b8e_row14_col16,#T_c0b8e_row14_col19,#T_c0b8e_row17_col41,#T_c0b8e_row20_col31,#T_c0b8e_row20_col32,#T_c0b8e_row21_col28,#T_c0b8e_row26_col24,#T_c0b8e_row28_col23,#T_c0b8e_row35_col41,#T_c0b8e_row38_col28,#T_c0b8e_row44_col42,#T_c0b8e_row46_col3,#T_c0b8e_row46_col19,#T_c0b8e_row47_col28{
#             background-color:  #2e00d1;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col11,#T_c0b8e_row2_col20,#T_c0b8e_row6_col4,#T_c0b8e_row6_col44,#T_c0b8e_row8_col5,#T_c0b8e_row8_col28,#T_c0b8e_row14_col36,#T_c0b8e_row15_col35,#T_c0b8e_row15_col39,#T_c0b8e_row17_col3,#T_c0b8e_row17_col49,#T_c0b8e_row18_col3,#T_c0b8e_row20_col9,#T_c0b8e_row23_col41,#T_c0b8e_row27_col3,#T_c0b8e_row27_col16,#T_c0b8e_row28_col14,#T_c0b8e_row29_col6,#T_c0b8e_row29_col23,#T_c0b8e_row35_col15,#T_c0b8e_row40_col17,#T_c0b8e_row43_col4,#T_c0b8e_row46_col23{
#             background-color:  #4400bb;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col12,#T_c0b8e_row0_col18,#T_c0b8e_row1_col45,#T_c0b8e_row7_col17,#T_c0b8e_row8_col38,#T_c0b8e_row11_col12,#T_c0b8e_row11_col15,#T_c0b8e_row11_col43,#T_c0b8e_row13_col31,#T_c0b8e_row15_col40,#T_c0b8e_row16_col4,#T_c0b8e_row16_col46,#T_c0b8e_row21_col27,#T_c0b8e_row22_col10,#T_c0b8e_row25_col17,#T_c0b8e_row26_col7,#T_c0b8e_row31_col9,#T_c0b8e_row31_col42,#T_c0b8e_row32_col10,#T_c0b8e_row32_col41,#T_c0b8e_row33_col17,#T_c0b8e_row34_col9,#T_c0b8e_row42_col48,#T_c0b8e_row45_col0,#T_c0b8e_row49_col44{
#             background-color:  #9c0063;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col13,#T_c0b8e_row3_col6,#T_c0b8e_row5_col4,#T_c0b8e_row9_col28,#T_c0b8e_row10_col27,#T_c0b8e_row15_col25,#T_c0b8e_row15_col45,#T_c0b8e_row18_col10,#T_c0b8e_row20_col3,#T_c0b8e_row20_col23,#T_c0b8e_row21_col49,#T_c0b8e_row23_col35,#T_c0b8e_row26_col6,#T_c0b8e_row27_col6,#T_c0b8e_row28_col42,#T_c0b8e_row28_col45,#T_c0b8e_row29_col19,#T_c0b8e_row30_col6,#T_c0b8e_row30_col24,#T_c0b8e_row33_col32,#T_c0b8e_row35_col16,#T_c0b8e_row39_col20,#T_c0b8e_row39_col23,#T_c0b8e_row39_col24,#T_c0b8e_row43_col25,#T_c0b8e_row48_col5,#T_c0b8e_row48_col13{
#             background-color:  #3000cf;
#             color:  #f1f1f1;
#         }#T_c0b8e_row0_col14,#T_c0b8e_row2_col17,#T_c0b8e_row2_col48,#T_c0b8e_row3_col10,#T_c0b8e_row6_col9,#T_c0b8e_row6_col18,#T_c0b8e_row8_col16,#T_c0b8e_row8_col41

# %% [markdown]
# #Correlation matrix for Weekly data

# %%
gain_loss_weekly = gain_loss_weekly.sort_values(by=["gain_loss"])
gain_25_daily = gain_loss_weekly.head(25)
loss_25_daily = gain_loss_weekly.tail(25)

gain_25_daily_names = list(gain_25_daily["symbol"])
loss_25_daily_names = list(loss_25_daily["symbol"])
names = set(loss_25_daily_names+gain_25_daily_names)
samp = pd.DataFrame(columns=names,index=names)
for n1,n2 in combinations(names,2):
    df1 = daily_dfs[n1]
    df2 = daily_dfs[n2]
    samp.loc[n1,n2] = df1["Gain/Loss"].corr(df2["Gain/Loss"])
    samp.loc[n2,n1] = df2["Gain/Loss"].corr(df1["Gain/Loss"])
    samp.loc[n1,n1] = 1
    samp.loc[n2,n2] = 1
weekly_samp = samp.astype({name:"float" for name in names})
weekly_samp.style.background_gradient(cmap="brg")
# Out:
# <style  type="text/css" >
# #T_b4a14_row0_col0,#T_b4a14_row1_col1,#T_b4a14_row2_col2,#T_b4a14_row3_col3,#T_b4a14_row4_col4,#T_b4a14_row5_col5,#T_b4a14_row6_col6,#T_b4a14_row7_col7,#T_b4a14_row8_col8,#T_b4a14_row9_col9,#T_b4a14_row10_col10,#T_b4a14_row11_col11,#T_b4a14_row12_col12,#T_b4a14_row13_col13,#T_b4a14_row14_col14,#T_b4a14_row15_col15,#T_b4a14_row16_col16,#T_b4a14_row17_col17,#T_b4a14_row18_col18,#T_b4a14_row19_col19,#T_b4a14_row20_col20,#T_b4a14_row21_col21,#T_b4a14_row22_col22,#T_b4a14_row23_col23,#T_b4a14_row24_col24,#T_b4a14_row25_col25,#T_b4a14_row26_col26,#T_b4a14_row27_col27,#T_b4a14_row28_col28,#T_b4a14_row29_col29,#T_b4a14_row30_col30,#T_b4a14_row31_col31,#T_b4a14_row32_col32,#T_b4a14_row33_col33,#T_b4a14_row34_col34,#T_b4a14_row35_col35,#T_b4a14_row36_col36,#T_b4a14_row37_col37,#T_b4a14_row38_col38,#T_b4a14_row39_col39,#T_b4a14_row40_col40,#T_b4a14_row41_col41,#T_b4a14_row42_col42,#T_b4a14_row43_col43,#T_b4a14_row44_col44,#T_b4a14_row45_col45,#T_b4a14_row46_col46,#T_b4a14_row47_col47,#T_b4a14_row48_col48,#T_b4a14_row49_col49{
#             background-color:  #00ff00;
#             color:  #000000;
#         }#T_b4a14_row0_col1,#T_b4a14_row0_col22,#T_b4a14_row0_col37,#T_b4a14_row4_col44,#T_b4a14_row14_col19,#T_b4a14_row16_col43,#T_b4a14_row18_col23,#T_b4a14_row19_col15,#T_b4a14_row27_col7,#T_b4a14_row27_col49,#T_b4a14_row29_col9,#T_b4a14_row35_col40,#T_b4a14_row44_col1,#T_b4a14_row44_col43,#T_b4a14_row48_col2,#T_b4a14_row48_col23{
#             background-color:  #1400eb;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col2,#T_b4a14_row0_col36,#T_b4a14_row0_col41,#T_b4a14_row4_col33,#T_b4a14_row9_col48,#T_b4a14_row11_col40,#T_b4a14_row18_col44,#T_b4a14_row19_col12,#T_b4a14_row19_col40,#T_b4a14_row22_col47,#T_b4a14_row26_col9,#T_b4a14_row27_col18,#T_b4a14_row29_col27,#T_b4a14_row30_col14,#T_b4a14_row31_col19,#T_b4a14_row34_col15,#T_b4a14_row34_col31,#T_b4a14_row35_col15,#T_b4a14_row35_col21,#T_b4a14_row40_col19,#T_b4a14_row43_col30,#T_b4a14_row44_col12{
#             background-color:  #2800d7;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col3,#T_b4a14_row3_col10,#T_b4a14_row9_col36,#T_b4a14_row12_col3,#T_b4a14_row12_col17,#T_b4a14_row15_col22,#T_b4a14_row15_col39,#T_b4a14_row21_col8,#T_b4a14_row25_col48,#T_b4a14_row26_col3,#T_b4a14_row26_col16,#T_b4a14_row31_col29,#T_b4a14_row31_col48,#T_b4a14_row35_col46,#T_b4a14_row36_col5,#T_b4a14_row36_col6,#T_b4a14_row39_col0,#T_b4a14_row41_col37,#T_b4a14_row45_col15,#T_b4a14_row47_col48{
#             background-color:  #94006b;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col4,#T_b4a14_row0_col10,#T_b4a14_row4_col17,#T_b4a14_row4_col34,#T_b4a14_row4_col39,#T_b4a14_row4_col48,#T_b4a14_row7_col22,#T_b4a14_row9_col31,#T_b4a14_row11_col1,#T_b4a14_row13_col34,#T_b4a14_row18_col16,#T_b4a14_row22_col30,#T_b4a14_row22_col39,#T_b4a14_row23_col19,#T_b4a14_row25_col49,#T_b4a14_row28_col22,#T_b4a14_row28_col40,#T_b4a14_row33_col4,#T_b4a14_row38_col18,#T_b4a14_row44_col49{
#             background-color:  #3600c9;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col5,#T_b4a14_row4_col28,#T_b4a14_row9_col11,#T_b4a14_row9_col35,#T_b4a14_row14_col44,#T_b4a14_row16_col27,#T_b4a14_row18_col0,#T_b4a14_row18_col45,#T_b4a14_row19_col2,#T_b4a14_row22_col7,#T_b4a14_row22_col45,#T_b4a14_row33_col23,#T_b4a14_row33_col49,#T_b4a14_row34_col12,#T_b4a14_row35_col12{
#             background-color:  #1800e7;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col6,#T_b4a14_row2_col45,#T_b4a14_row3_col23,#T_b4a14_row6_col13,#T_b4a14_row7_col14,#T_b4a14_row10_col35,#T_b4a14_row14_col42,#T_b4a14_row20_col7,#T_b4a14_row24_col15,#T_b4a14_row24_col21,#T_b4a14_row28_col31,#T_b4a14_row31_col3,#T_b4a14_row31_col9,#T_b4a14_row31_col26,#T_b4a14_row35_col0,#T_b4a14_row40_col26,#T_b4a14_row41_col5,#T_b4a14_row49_col33{
#             background-color:  #74008b;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col7,#T_b4a14_row2_col34,#T_b4a14_row4_col29,#T_b4a14_row7_col40,#T_b4a14_row8_col40,#T_b4a14_row13_col44,#T_b4a14_row14_col29,#T_b4a14_row14_col39,#T_b4a14_row17_col1,#T_b4a14_row18_col14,#T_b4a14_row19_col4,#T_b4a14_row25_col31,#T_b4a14_row26_col31,#T_b4a14_row30_col2,#T_b4a14_row30_col4,#T_b4a14_row30_col10,#T_b4a14_row36_col8,#T_b4a14_row38_col21,#T_b4a14_row39_col10,#T_b4a14_row44_col7,#T_b4a14_row46_col32{
#             background-color:  #4000bf;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col8,#T_b4a14_row0_col30,#T_b4a14_row1_col24,#T_b4a14_row2_col49,#T_b4a14_row6_col49,#T_b4a14_row14_col15,#T_b4a14_row16_col11,#T_b4a14_row21_col31,#T_b4a14_row21_col47,#T_b4a14_row24_col0,#T_b4a14_row25_col24,#T_b4a14_row26_col24,#T_b4a14_row28_col20,#T_b4a14_row34_col28,#T_b4a14_row35_col8,#T_b4a14_row35_col39,#T_b4a14_row38_col44,#T_b4a14_row39_col6,#T_b4a14_row43_col40,#T_b4a14_row44_col35,#T_b4a14_row46_col24{
#             background-color:  #960069;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col9,#T_b4a14_row0_col18,#T_b4a14_row7_col9,#T_b4a14_row8_col36,#T_b4a14_row13_col6,#T_b4a14_row14_col33,#T_b4a14_row14_col34,#T_b4a14_row16_col41,#T_b4a14_row18_col32,#T_b4a14_row18_col42,#T_b4a14_row18_col46,#T_b4a14_row19_col27,#T_b4a14_row22_col28,#T_b4a14_row25_col23,#T_b4a14_row27_col22,#T_b4a14_row27_col38,#T_b4a14_row28_col4,#T_b4a14_row28_col23,#T_b4a14_row35_col31,#T_b4a14_row35_col41,#T_b4a14_row38_col27,#T_b4a14_row43_col46,#T_b4a14_row44_col37,#T_b4a14_row47_col27{
#             background-color:  #2e00d1;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col11,#T_b4a14_row2_col22,#T_b4a14_row2_col39,#T_b4a14_row7_col25,#T_b4a14_row9_col14,#T_b4a14_row15_col46,#T_b4a14_row16_col6,#T_b4a14_row21_col11,#T_b4a14_row21_col24,#T_b4a14_row23_col29,#T_b4a14_row24_col1,#T_b4a14_row31_col32,#T_b4a14_row36_col47,#T_b4a14_row40_col25,#T_b4a14_row42_col39,#T_b4a14_row42_col46,#T_b4a14_row43_col37,#T_b4a14_row47_col40,#T_b4a14_row49_col13,#T_b4a14_row49_col34{
#             background-color:  #860079;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col12,#T_b4a14_row4_col3,#T_b4a14_row4_col19,#T_b4a14_row9_col33,#T_b4a14_row13_col23,#T_b4a14_row14_col0,#T_b4a14_row14_col48,#T_b4a14_row19_col41,#T_b4a14_row27_col42,#T_b4a14_row35_col37,#T_b4a14_row35_col49,#T_b4a14_row38_col36,#T_b4a14_row46_col9,#T_b4a14_row48_col12,#T_b4a14_row48_col14{
#             background-color:  #2000df;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col13,#T_b4a14_row1_col34,#T_b4a14_row2_col16,#T_b4a14_row2_col26,#T_b4a14_row2_col48,#T_b4a14_row7_col41,#T_b4a14_row12_col19,#T_b4a14_row13_col7,#T_b4a14_row13_col30,#T_b4a14_row14_col20,#T_b4a14_row23_col8,#T_b4a14_row23_col34,#T_b4a14_row23_col35,#T_b4a14_row26_col14,#T_b4a14_row27_col4,#T_b4a14_row30_col18,#T_b4a14_row31_col27,#T_b4a14_row31_col44,#T_b4a14_row38_col10,#T_b4a14_row39_col31,#T_b4a14_row40_col29,#T_b4a14_row42_col16{
#             background-color:  #5a00a5;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col14,#T_b4a14_row0_col31,#T_b4a14_row5_col21,#T_b4a14_row7_col32,#T_b4a14_row8_col1,#T_b4a14_row8_col22,#T_b4a14_row9_col10,#T_b4a14_row9_col20,#T_b4a14_row11_col10,#T_b4a14_row11_col31,#T_b4a14_row13_col21,#T_b4a14_row13_col24,#T_b4a14_row14_col35,#T_b4a14_row16_col14,#T_b4a14_row18_col38,#T_b4a14_row18_col40,#T_b4a14_row19_col32,#T_b4a14_row23_col0,#T_b4a14_row26_col49,#T_b4a14_row32_col0,#T_b4a14_row33_col7,#T_b4a14_row34_col4,#T_b4a14_row35_col20,#T_b4a14_row40_col3,#T_b4a14_row40_col8,#T_b4a14_row41_col19,#T_b4a14_row43_col18,#T_b4a14_row43_col38,#T_b4a14_row43_col48,#T_b4a14_row46_col4,#T_b4a14_row46_col40{
#             background-color:  #3a00c5;
#             color:  #f1f1f1;
#         }#T_b4a14_row0_col15,#T_b4a14_row0_col32,#T_b4a14_row0_col40,#T_b4a14_row4_col16,#T_b4a14_row9_col29,#T_b4a14_row9_col45,#T_b4a14_row13_col9,#T_b4a14_row13_col10,#T_b4a14_row13_col18,#T_b4a14_row13_col41,#T_b4a14_row14_col38,#T_b4a14_row16_col4,#T_b4a14_row16_col12,#T_b4a14_row16_col23,#T_b4a14_row16_col36,#T_b4a14_row16_col42,#T_b4a14_row18_col2,#T_b4a14_row18_col3,#T_b4a14_row18_col5,#T_b4a14_

# %% [markdown]
# #Correlation matrix for monthly data

# %%
gain_loss_monthly = gain_loss_monthly.sort_values(by=["gain_loss"])
gain_25_daily = gain_loss_monthly.head(25)
loss_25_daily = gain_loss_monthly.tail(25)

gain_25_daily_names = list(gain_25_daily["symbol"])
loss_25_daily_names = list(loss_25_daily["symbol"])

names = set(loss_25_daily_names+gain_25_daily_names)
samp = pd.DataFrame(columns=names,index=names)
for n1,n2 in combinations(names,2):
    df1 = daily_dfs[n1]
    df2 = daily_dfs[n2]
    samp.loc[n1,n2] = df1["Gain/Loss"].corr(df2["Gain/Loss"])
    samp.loc[n2,n1] = df2["Gain/Loss"].corr(df1["Gain/Loss"])
    samp.loc[n1,n1] = 1
    samp.loc[n2,n2] = 1
monthly_samp = samp.astype({name:"float" for name in names})
monthly_samp.style.background_gradient(cmap="brg")
# Out:
# <style  type="text/css" >
# #T_bc874_row0_col0,#T_bc874_row1_col1,#T_bc874_row2_col2,#T_bc874_row3_col3,#T_bc874_row4_col4,#T_bc874_row5_col5,#T_bc874_row6_col6,#T_bc874_row7_col7,#T_bc874_row8_col8,#T_bc874_row9_col9,#T_bc874_row10_col10,#T_bc874_row11_col11,#T_bc874_row12_col12,#T_bc874_row13_col13,#T_bc874_row14_col14,#T_bc874_row15_col15,#T_bc874_row16_col16,#T_bc874_row17_col17,#T_bc874_row18_col18,#T_bc874_row19_col19,#T_bc874_row20_col20,#T_bc874_row21_col21,#T_bc874_row22_col22,#T_bc874_row23_col23,#T_bc874_row24_col24,#T_bc874_row25_col25,#T_bc874_row26_col26,#T_bc874_row27_col27,#T_bc874_row28_col28,#T_bc874_row29_col29,#T_bc874_row30_col30,#T_bc874_row31_col31,#T_bc874_row32_col32,#T_bc874_row33_col33,#T_bc874_row34_col34,#T_bc874_row35_col35,#T_bc874_row36_col36,#T_bc874_row37_col37,#T_bc874_row38_col38,#T_bc874_row39_col39,#T_bc874_row40_col40,#T_bc874_row41_col41,#T_bc874_row42_col42,#T_bc874_row43_col43,#T_bc874_row44_col44,#T_bc874_row45_col45,#T_bc874_row46_col46,#T_bc874_row47_col47,#T_bc874_row48_col48,#T_bc874_row49_col49{
#             background-color:  #00ff00;
#             color:  #000000;
#         }#T_bc874_row0_col1,#T_bc874_row1_col0,#T_bc874_row3_col48,#T_bc874_row6_col16,#T_bc874_row6_col43,#T_bc874_row8_col5,#T_bc874_row9_col31,#T_bc874_row10_col34,#T_bc874_row13_col44,#T_bc874_row15_col2,#T_bc874_row22_col24,#T_bc874_row23_col14,#T_bc874_row24_col0,#T_bc874_row26_col10,#T_bc874_row27_col16,#T_bc874_row31_col32,#T_bc874_row43_col10,#T_bc874_row44_col1,#T_bc874_row44_col14,#T_bc874_row46_col16{
#             background-color:  #a0005f;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col2,#T_bc874_row0_col18,#T_bc874_row8_col16,#T_bc874_row13_col5,#T_bc874_row15_col22,#T_bc874_row18_col34,#T_bc874_row28_col16,#T_bc874_row43_col0,#T_bc874_row43_col3,#T_bc874_row44_col18,#T_bc874_row44_col25,#T_bc874_row45_col31,#T_bc874_row46_col2{
#             background-color:  #6a0095;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col3,#T_bc874_row0_col41,#T_bc874_row2_col17,#T_bc874_row3_col42,#T_bc874_row5_col28,#T_bc874_row15_col13,#T_bc874_row21_col22,#T_bc874_row22_col29,#T_bc874_row22_col40,#T_bc874_row25_col29,#T_bc874_row26_col44,#T_bc874_row27_col25,#T_bc874_row28_col14,#T_bc874_row28_col27,#T_bc874_row34_col1,#T_bc874_row35_col33,#T_bc874_row36_col0,#T_bc874_row40_col30,#T_bc874_row41_col48,#T_bc874_row48_col3{
#             background-color:  #92006d;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col4,#T_bc874_row4_col8,#T_bc874_row8_col4,#T_bc874_row11_col29,#T_bc874_row13_col7,#T_bc874_row13_col10,#T_bc874_row14_col4,#T_bc874_row15_col19,#T_bc874_row15_col36,#T_bc874_row15_col49,#T_bc874_row23_col7,#T_bc874_row24_col7,#T_bc874_row27_col42,#T_bc874_row29_col11,#T_bc874_row29_col19,#T_bc874_row29_col24,#T_bc874_row29_col35,#T_bc874_row30_col13,#T_bc874_row32_col26,#T_bc874_row35_col10,#T_bc874_row35_col17,#T_bc874_row37_col25,#T_bc874_row37_col27,#T_bc874_row41_col11,#T_bc874_row42_col41,#T_bc874_row49_col21{
#             background-color:  #f0000f;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col5,#T_bc874_row3_col41,#T_bc874_row6_col28,#T_bc874_row7_col22,#T_bc874_row7_col25,#T_bc874_row9_col6,#T_bc874_row9_col45,#T_bc874_row9_col47,#T_bc874_row13_col40,#T_bc874_row18_col47,#T_bc874_row25_col30,#T_bc874_row25_col31,#T_bc874_row27_col31,#T_bc874_row31_col25,#T_bc874_row34_col5,#T_bc874_row34_col16,#T_bc874_row34_col22,#T_bc874_row38_col40,#T_bc874_row44_col43,#T_bc874_row46_col28{
#             background-color:  #780087;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col6,#T_bc874_row4_col5,#T_bc874_row6_col30,#T_bc874_row6_col48,#T_bc874_row8_col15,#T_bc874_row11_col3,#T_bc874_row14_col0,#T_bc874_row16_col38,#T_bc874_row22_col7,#T_bc874_row23_col19,#T_bc874_row24_col2,#T_bc874_row26_col30,#T_bc874_row30_col14,#T_bc874_row32_col9,#T_bc874_row32_col44,#T_bc874_row34_col41,#T_bc874_row36_col10,#T_bc874_row38_col33,#T_bc874_row39_col36,#T_bc874_row42_col22,#T_bc874_row42_col44,#T_bc874_row44_col6,#T_bc874_row45_col15,#T_bc874_row47_col34,#T_bc874_row47_col36,#T_bc874_row48_col33{
#             background-color:  #a2005d;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col7,#T_bc874_row4_col0,#T_bc874_row4_col19,#T_bc874_row10_col13,#T_bc874_row14_col5,#T_bc874_row15_col26,#T_bc874_row17_col37,#T_bc874_row18_col43,#T_bc874_row19_col15,#T_bc874_row24_col45,#T_bc874_row27_col1,#T_bc874_row27_col49,#T_bc874_row32_col36,#T_bc874_row35_col7,#T_bc874_row35_col45,#T_bc874_row38_col4,#T_bc874_row40_col5,#T_bc874_row41_col33,#T_bc874_row41_col43,#T_bc874_row43_col5,#T_bc874_row45_col8,#T_bc874_row47_col49{
#             background-color:  #f2000d;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col8,#T_bc874_row0_col42,#T_bc874_row0_col49,#T_bc874_row1_col23,#T_bc874_row1_col38,#T_bc874_row5_col2,#T_bc874_row5_col27,#T_bc874_row6_col11,#T_bc874_row6_col13,#T_bc874_row10_col0,#T_bc874_row11_col30,#T_bc874_row13_col6,#T_bc874_row13_col33,#T_bc874_row14_col2,#T_bc874_row16_col23,#T_bc874_row17_col15,#T_bc874_row17_col36,#T_bc874_row19_col9,#T_bc874_row23_col3,#T_bc874_row25_col11,#T_bc874_row26_col2,#T_bc874_row27_col40,#T_bc874_row28_col11,#T_bc874_row30_col33,#T_bc874_row31_col42,#T_bc874_row32_col25,#T_bc874_row35_col11,#T_bc874_row35_col24,#T_bc874_row35_col37,#T_bc874_row37_col9,#T_bc874_row39_col32,#T_bc874_row40_col27,#T_bc874_row44_col23{
#             background-color:  #b60049;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col9,#T_bc874_row2_col30,#T_bc874_row5_col34,#T_bc874_row8_col31,#T_bc874_row9_col29,#T_bc874_row16_col2,#T_bc874_row16_col25,#T_bc874_row22_col13,#T_bc874_row22_col28,#T_bc874_row31_col6,#T_bc874_row31_col17,#T_bc874_row31_col47,#T_bc874_row35_col5,#T_bc874_row39_col2,#T_bc874_row41_col16,#T_bc874_row44_col2,#T_bc874_row46_col31{
#             background-color:  #64009b;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col10,#T_bc874_row1_col21,#T_bc874_row1_col31,#T_bc874_row5_col41,#T_bc874_row7_col1,#T_bc874_row9_col14,#T_bc874_row10_col19,#T_bc874_row16_col3,#T_bc874_row16_col45,#T_bc874_row22_col42,#T_bc874_row23_col11,#T_bc874_row32_col40,#T_bc874_row36_col29,#T_bc874_row37_col44,#T_bc874_row38_col34,#T_bc874_row39_col35,#T_bc874_row41_col9,#T_bc874_row42_col6,#T_bc874_row44_col11,#T_bc874_row48_col19{
#             background-color:  #bc0043;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col11,#T_bc874_row2_col5,#T_bc874_row2_col33,#T_bc874_row3_col24,#T_bc874_row4_col15,#T_bc874_row4_col16,#T_bc874_row6_col24,#T_bc874_row6_col42,#T_bc874_row8_col26,#T_bc874_row9_col37,#T_bc874_row9_col41,#T_bc874_row10_col1,#T_bc874_row10_col16,#T_bc874_row10_col44,#T_bc874_row11_col21,#T_bc874_row14_col9,#T_bc874_row16_col49,#T_bc874_row19_col10,#T_bc874_row19_col48,#T_bc874_row23_col8,#T_bc874_row23_col35,#T_bc874_row26_col21,#T_bc874_row33_col8,#T_bc874_row34_col47,#T_bc874_row36_col28,#T_bc874_row38_col8,#T_bc874_row39_col33,#T_bc874_row41_col38,#T_bc874_row43_col31,#T_bc874_row44_col24,#T_bc874_row46_col26{
#             background-color:  #be0041;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col12,#T_bc874_row12_col44,#T_bc874_row12_col49,#T_bc874_row19_col12,#T_bc874_row26_col12,#T_bc874_row38_col20{
#             background-color:  #0c00f3;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col13,#T_bc874_row0_col23,#T_bc874_row6_col38,#T_bc874_row6_col41,#T_bc874_row7_col14,#T_bc874_row8_col0,#T_bc874_row9_col15,#T_bc874_row14_col39,#T_bc874_row16_col6,#T_bc874_row16_col17,#T_bc874_row16_col37,#T_bc874_row26_col8,#T_bc874_row28_col19,#T_bc874_row28_col33,#T_bc874_row28_col36,#T_bc874_row28_col49,#T_bc874_row30_col1,#T_bc874_row31_col26,#T_bc874_row33_col2,#T_bc874_row33_col6,#T_bc874_row34_col19,#T_bc874_row34_col37,#T_bc874_row36_col13,#T_bc874_row36_col47,#T_bc874_row41_col15,#T_bc874_row41_col46,#T_bc874_row44_col19,#T_bc874_row47_col1,#T_bc874_row47_col33,#T_bc874_row48_col23{
#             background-color:  #b80047;
#             color:  #f1f1f1;
#         }#T_bc874_row0_col14,#

# %% [markdown]
# # 4.	For each company in top 25 and bottom 25, identify their GICS sectors from https://en.wikipedia.org/wiki/List_of_S%26P_500_companies and draw a bar graph depicting number of top 25 and bottom 25 belongs to that sector.  Do the same thing for weekly and monthly data.

# %%
#here we take the top and bottom 25 values to plot the bar graph.
top_25 = dict(gain_loss_daily["GICS"].head(25).value_counts())
bottom_25 = dict(gain_loss_daily["GICS"].tail(25).value_counts())
labels = set(list(top_25.keys()) + list(bottom_25.keys()))


for lab in labels:
    if lab in top_25:
        pass
    else:
        top_25[lab] = 0
    if lab in bottom_25:
        pass
    else:
        bottom_25[lab] = 0
#here we use plt library to draw the bar graph. by giving appropriate colors.
w = 0.2
ind = np.arange(len(labels))
ind2 = [i+w for i in ind]
plt.bar(ind,top_25.values(),w,color="r",label="top")
plt.bar(ind2,bottom_25.values(),w,color="b",label="bottom")
#for x- axis we give gisc sectors
plt.xlabel("gisc")
#for y - axis we give frequency.
plt.ylabel("frequency")
plt.xticks(ind+w/2,labels,rotation=90)
plt.title("daily")
plt.legend()

# %%
#here we take the top and bottom 25 values to plot the bar graph.
top_25 = dict(gain_loss_weekly["GICS"].head(25).value_counts())
bottom_25 = dict(gain_loss_weekly["GICS"].tail(25).value_counts())
labels = set(list(top_25.keys()) + list(bottom_25.keys()))


for lab in labels:
    if lab in top_25:
        pass
    else:
        top_25[lab] = 0
    if lab in bottom_25:
        pass
    else:
        bottom_25[lab] = 0
#here we use plt library to draw the bar graph. by giving appropriate colors.
w = 0.2
ind = np.arange(len(labels))
ind2 = [i+w for i in ind]
plt.bar(ind,top_25.values(),w,color="r",label="top")
plt.bar(ind2,bottom_25.values(),w,color="b",label="bottom")
#for x- axis we give gisc sectors
plt.xlabel("gisc")
#for y - axis we give frequency.
plt.ylabel("frequency")
plt.xticks(ind+w/2,labels,rotation=90)
plt.title("weekly")
plt.legend()

# %%
#here we take the top and bottom 25 values to plot the bar graph.
top_25 = dict(gain_loss_monthly["GICS"].head(25).value_counts())
bottom_25 = dict(gain_loss_monthly["GICS"].tail(25).value_counts())
labels = set(list(top_25.keys()) + list(bottom_25.keys()))


for lab in labels:
    if lab in top_25:
        pass
    else:
        top_25[lab] = 0
    if lab in bottom_25:
        pass
    else:
        bottom_25[lab] = 0
#here we use plt library to draw the bar graph. by giving appropriate colors.
w = 0.2
ind = np.arange(len(labels))
ind2 = [i+w for i in ind]
plt.bar(ind,top_25.values(),w,color="r",label="top")
plt.bar(ind2,bottom_25.values(),w,color="b",label="bottom")
#for x- axis we give gisc sectors
plt.xlabel("gisc")
#for y - axis we give frequency.
plt.ylabel("frequency")
plt.xticks(ind+w/2,labels,rotation=90)
plt.title("monthly")
plt.legend()

# %% [markdown]
# # 5.	For the top 2 companies, find the maximum negatively correlated companies in the remaining 48 companies from the correlation matrix.  Using Tornado templates, draw sparkline plots of the 4 companies of their daily gains or losses in the same chart. Do the same thing for weekly and monthly gains or losses. Do the same thing for bottom 2 companies. Convert these files into PDF without using a browser.

# %%
import base64

#for the purpose of building a spark line graph, we have to write this spark line method.
#parameters passed are data we pass about the 2 and 48 compnaies.

def spark_line(data, figsize=(4, 0.25), **kwags):
    """
    This method will Returns a HTML image tag containing a base64 encoded sparkline style plot
    """
    data = list(data)

    fig, ax = plt.subplots(1, 1, figsize=figsize, **kwags)
    ax.plot(data)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])

    plt.plot(len(data) - 1, data[len(data) - 1], 'r.')

    ax.fill_between(range(len(data)), data, len(data)*[min(data)], alpha=0.1)
    
    #IO.bytes() will convert the web text to bytes and then embeds as an spark line image.
    img = io.BytesIO()
    plt.savefig(img, transparent=True, bbox_inches='tight')
    img.seek(0)
    plt.close()

    return base64.b64encode(img.read()).decode("UTF-8")

# %%
#Finding the negatively correlated companies for the top 2 companies - DAILY
top_four = list()
top_2 = gain_loss_daily.head(2)

#checking for the symbols and sorting values for each symbol.
for sym in top_2["symbol"]:
    tsym = daily_samp[sym].sort_values().index[0]
    top_four.append(sym)
    top_four.append(tsym)
    
#in this we use dropna() method to avoid the NA/NaN values in data.
all_values = list()
for num in top_four:
    val = list(daily_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
#It opens the sparline for comparision.
with open("spark1.html", "a") as file:
        file.write('<div>Daily top</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

#Doing the same above process in the bottom 2 companies.
bottom_four = list()
bottom_2 = gain_loss_daily.tail(2)
for sym in bottom_2["symbol"]:
    tsym = daily_samp[sym].sort_values().index[0]
    bottom_four.append(sym)
    bottom_four.append(tsym)
all_values = list()

for num in bottom_four:
    val = list(daily_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
with open("spark1.html", "a") as file:
        file.write('<div>Daily bottom</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

# %%
#Finding the negatively correlated companies for the top 2 companies - weekly
top_four = list()
top_2 = gain_loss_weekly.head(2)

#checking for the symbols and sorting values for each symbol.
for sym in top_2["symbol"]:
    tsym = weekly_samp[sym].sort_values().index[0]
    top_four.append(sym)
    top_four.append(tsym)
    
#in this we use dropna() method to avoid the NA/NaN values in data.
all_values = list()
for num in top_four:
    val = list(weekly_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
#It opens the sparline for comparision.
with open("spark1.html", "a") as file:
        file.write('<div>Weekly top</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

#Doing the same above process in the bottom 2 companies.
bottom_four = list()
bottom_2 = gain_loss_weekly.tail(2)
for sym in bottom_2["symbol"]:
    tsym = weekly_samp[sym].sort_values().index[0]
    bottom_four.append(sym)
    bottom_four.append(tsym)
all_values = list()

for num in bottom_four:
    val = list(weekly_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
with open("spark1.html", "a") as file:
        file.write('<div>Weekly bottom</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

# %%
#Finding the negatively correlated companies for the top 2 companies - monthly
top_four = list()
top_2 = gain_loss_monthly.head(2)

#checking for the symbols and sorting values for each symbol.
for sym in top_2["symbol"]:
    tsym = monthly_samp[sym].sort_values().index[0]
    top_four.append(sym)
    top_four.append(tsym)
    
#in this we use dropna() method to avoid the NA/NaN values in data.
all_values = list()
for num in top_four:
    val = list(monthly_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
#It opens the sparline for comparision.
with open("spark1.html", "a") as file:
        file.write('<div>Monthly top</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

#Doing the same above process in the bottom 2 companies.
bottom_four = list()
bottom_2 = gain_loss_monthly.tail(2)
for sym in bottom_2["symbol"]:
    tsym = monthly_samp[sym].sort_values().index[0]
    bottom_four.append(sym)
    bottom_four.append(tsym)
all_values = list()

for num in bottom_four:
    val = list(monthly_dfs[num]["Gain/Loss"].dropna().values)
    all_values.append(val)
    
with open("spark1.html", "a") as file:
        file.write('<div>Monthly bottom</div>')
        for value in all_values:
            file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

# %%
pip install pdfcrowd
# Out:
# Requirement already satisfied: pdfcrowd in c:\users\ranjith\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (5.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfcrowd

client = pdfcrowd.HtmlToPdfClient('demo', 'ce544b6ea52a5621fb9d55f8b542d14d')
client.convertFileToFile('spark1.html', 'spark1.pdf')
